# %% [markdown]
# What are recommender systems?
# It helps the user to select the right item by suggesting a presumable list of items and so it has become an integral part of e-commerce, movie and music rendering sites and the list goes on. They are becoming one of the most popular applications of machine learning which has gained importance in recent years. The two most popular ways it can be approached/built are:
#
# 1- Content-based recommendations .
#
# 2- Collaborative FIltering .
#
# In this , we will be focussing on the Content-based recommendations that is: the user is recommended items that are similar to the content he/she liked previously.
#
# We will be working with MovieLens Dataset, a movie rating dataset, to develop a recommendation system using the surprise library. Let's get started!

# %%
import pandas as pd
import numpy as np
import random
from math import *
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("movie_dataset.csv")
features = ['keywords','cast','genres','director']
def combine_features(row):
    return row['keywords']+" "+row['cast']+" "+row['genres']+" "+row['director']

# %%
for feature in features:
    df[feature] = df[feature].fillna('')
df["combined_features"] = df.apply(combine_features,axis=1)
#df.iloc[0].combined_features

# %%
cv = CountVectorizer() 
count_matrix = cv.fit_transform(df["combined_features"])
cosine_sim = cosine_similarity(count_matrix)
def get_title_from_index(index):
    return df[df.index == index]["title"].values[0]
def get_index_from_title(title):
    return df[df.title == title]["index"].values[0]

# %%
movie_user_likes = "Spectre"
movie_index = get_index_from_title(movie_user_likes)
similar_movies = list(enumerate(cosine_sim[movie_index]))
sorted_similar_movies = sorted(similar_movies,key=lambda x:x[1],reverse=True)[1:]

# %%
i=0
print("Top 5 similar movies to "+movie_user_likes+" are:\n")
for element in sorted_similar_movies:
    print(get_title_from_index(element[0]))
    i=i+1
    if i>5:
        break
# Out:
# Top 5 similar movies to Spectre are:
#
# Deadfall
# The Devil's Own
# AWOL-72
# Jack Reacher
# The One
# Lethal Weapon 3

# %%
df1 = pd.read_csv("movie_dataset.csv")
df1=pd.DataFrame(df1, columns=['title'])
df1 = df1['title'].to_list()
#print('List of Titles: ', df1)
#print('Type of listOfTitle: ', type(df1))
u1 = random.sample(df1,1127)
print ("Random selected title for u1 : " + str(u1))
u2 = random.sample(df1,1689)
print ("Random selected title for u2 : " + str(u2))
u3 = random.sample(df1,1988)
print ("Random selected title for u3 : " + str(u3))
u4 = random.sample(df1,1646)
print ("Random selected title for u4 : " + str(u4))
u5 = random.sample(df1,1725)
print ("Random selected title for u5 : " + str(u5))
# Out:
# Random selected title for u1 : ['A Walk on the Moon', 'The Veil', 'The Cold Light of Day', 'Sphinx', 'Syriana', 'Frequency', 'Big', 'Must Love Dogs', 'Apollo 18', 'Bridesmaids', 'Old Dogs', "Happily N'Ever After", 'The Hammer', 'Collateral', 'Clash of the Titans', 'The Finest Hours', 'The Mask', 'Winnie Mandela', "Madea's Family Reunion", 'Need for Speed', 'The Informers', 'The Crew', 'Very Bad Things', "Buffalo '66", 'Pirate Radio', 'Loving Annabelle', 'The Kingdom', 'Money Monster', 'Her Cry: La Llorona Investigation', 'Star Trek', 'From Justin to Kelly', 'RoboCop', 'Penguins of Madagascar', 'PokÃ©mon 3: The Movie', 'Lincoln', 'Clerks', 'Running Forever', 'The Land Girls', 'Dune', 'Flags of Our Fathers', 'Paranormal Activity', 'On the Waterfront', 'Die Another Day', 'Of Horses and Men', 'Remember Me', 'Flubber', 'Signed Sealed Delivered', 'The Hunt for Red October', 'Metropolis', 'The Good Dinosaur', 'War', 'Caddyshack', 'Solitude', 'Punch-Drunk Love', 'Hide and Seek', 'The Dangerous Lives of Altar Boys', 'The Rocker', 'Grace Unplugged', 'The Muppet Movie', 'Ben-Hur', 'The Alamo', 'Raiders of the Lost Ark', 'The Lego Movie', 'Daddy Day Care', 'Dodgeball: A True Underdog Story', 'Graduation Day', 'Taxi Driver', 'Gabriela', 'Basquiat', 'Final Destination 2', 'Something Borrowed', "Tim and Eric's Billion Dollar Movie", 'Ghost Rider', 'The Work and the Story', 'Across the Universe', 'The Lovers', 'Indiana Jones and the Last Crusade', 'The Rocket: The Legend of Rocket Richard', 'This Is 40', 'Antiviral', 'This Means War', 'The Best Little Whorehouse in Texas', 'Random Hearts', 'All Superheroes Must Die', 'The Thomas Crown Affair', 'Aliens', 'Skyfall', 'For Love of the Game', 'Obitaemyy ostrov', 'Three Kingdoms: Resurrection of the Dragon', 'Definitely, Maybe', 'The Boss', 'Joe Somebody', 'The Vatican Tapes', "Bram Stoker's Dracula", 'Henry V', 'Hotel Rwanda', 'Taken 3', "Trippin'", '50/50', 'The Legend of Tarzan', 'Monsters, Inc.', "Doug's 1st Movie", 'Soul Survivors', 'Mr. Peabody & Sherman', 'Big Trouble', 'The Waterboy', 'ZMD: Zombies of Mass Destruction', 'Pixels', 'The Calling', 'What a Girl Wants', 'Airlift', 'Dumb & Dumber', 'Aliens in the Attic', 'What Women Want', 'The Company', 'Detroit Rock City', 'Lords of Dogtown', 'The Devil Inside', 'The Iron Giant', 'The Way of the Gun', 'Ted', 'Out of Sight', 'The Signal', 'Legend of Kung Fu Rabbit', 'Elsa & Fred', 'The Adventurer: The Curse of the Midas Box', 'Mission: Impossible III', 'The Long Kiss Goodnight', "No Man's Land: The Rise of Reeker", 'Dark Angel', 'Area 51', 'Taxi to the Dark Side', 'The Punisher', 'High Tension', 'Blue Like Jazz', 'Princess Mononoke', 'Breakdown', 'Yeh Jawaani Hai Deewani', 'Be Kind Rewind', 'Aquamarine', 'Another Year', 'Hayride', 'I Still Know What You Did Last Summer', 'Held Up', 'Home on the Range', 'Wild Target', 'Hatchet', 'The Possession', 'Melancholia', "Winter's Bone", 'Show Boat', 'A Night at the Roxbury', 'The Last Exorcism Part II', 'Saw VI', 'Major Dundee', 'Under the Tuscan Sun', "My Best Friend's Wedding", 'Clear and Present Danger', 'RED', 'The Girl on the Train', 'Snitch', 'Appaloosa', 'Before I Go to Sleep', 'Small Apartments', 'Lottery Ticket', 'How High', 'Tristram Shandy: A Cock and Bull Story', 'It Follows', '8MM', 'Return to Oz', "What's Eating Gilbert Grape", 'Dreamgirls', 'The Timber', 'Resident Evil: Extinction', 'Goosebumps', 'BrÃ¼no', 'Lolita', 'The 13th Warrior', 'The Toxic Avenger Part II', "When the Cat's Away", 'Freeze Frame', "She's Gotta Have It", 'UnDivided', 'The Descent', 'Outlander', 'Party Monster', 'Outbreak', 'The Heart of Me', 'American Reunion', 'Southland Tales', 'Birthday Girl', 'Welcome to the Dollhouse', 'Ghost', 'Partition', 'The Californians', 'Sky Captain and the World of Tomorrow', 'Ghost Rider: Spirit of Vengeance', 'Prom', 'The Work and the Glory', 'Romeo + Juliet', 'Hum To Mohabbat Karega', 'Dr. Dolittle 2', 'Chicken Tikka Masala', 'Duel in the Sun', 'The Great Gatsby', 'The Transporter', 'The ...
# Random selected title for u2 : ['Letters to Juliet', 'Mars Needs Moms', "Straight A's", 'Because of Winn-Dixie', '10,000 B.C.            ', 'J. Edgar', '12 Rounds', 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 'Somewhere', 'Kabhi Alvida Naa Kehna', 'Edtv', 'Mystic Pizza', 'Planet of the Apes', 'Skyfall', 'Reservoir Dogs', 'The Ides of March', "Heaven's Gate", 'Howard the Duck', 'London to Brighton', 'Letters to God', 'The SpongeBob Movie: Sponge Out of Water', 'Into the Wild', 'The Bourne Legacy', 'The Jacket', 'Next Friday', 'Wristcutters: A Love Story', 'Treachery', 'Black Snake Moan', 'The Last Witch Hunter', 'Party Monster', 'Fun with Dick and Jane', 'Stolen Summer', 'Amadeus', 'The Omen', 'Antwone Fisher', 'Slither', 'The Masked Saint', 'Wag the Dog', 'Snow Flower and the Secret Fan', 'Dick Tracy', 'Airlift', 'Bella', 'The Little Ponderosa Zoo', 'Side Effects', 'The Family', 'Tiny Furniture', 'A Funny Thing Happened on the Way to the Forum', 'The Tailor of Panama', 'First Knight', 'Hearts in Atlantis', 'Riding Giants', 'Slam', 'Need for Speed', 'Get on the Bus', 'Dangerous Liaisons', 'Spy Kids 2: Island of Lost Dreams', 'Men of War', 'Domino', 'Zack and Miri Make a Porno', 'Pain & Gain', 'To Save a Life', 'The Interview', 'Click', 'Jane Got a Gun', 'Victor Frankenstein', 'American Wedding', 'Sex Drive', 'Jackass 3D', 'Shaun of the Dead', 'The Lovers', 'Avengers: Age of Ultron', 'Tanner Hall', 'In Dreams', 'The Lovely Bones', 'Sur le seuil', 'Our Brand Is Crisis', 'Moon', 'The Muse', 'Bizarre', "The Hitchhiker's Guide to the Galaxy", 'Big Fish', 'The Holiday', "Child's Play", 'Lone Survivor', 'In the Bedroom', 'Bad Santa', 'Deep Impact', 'Spartacus: War of the Damned', 'Minority Report', 'The Virgin Suicides', 'Adore', 'Pinocchio', 'Jumping the Broom', 'Love Letters', 'Yes', 'House of 1000 Corpses', 'Frost/Nixon', 'House of D', 'Book of Shadows: Blair Witch 2', 'The Birth of a Nation', 'Go for It!', 'The Fast and the Furious', 'America Is Still the Place', 'The Invasion', 'From a Whisper to a Scream', 'Run, Fatboy, Run', 'Viy', 'Slackers', 'Kicking & Screaming', 'Water & Power', 'Beer League', 'Rachel Getting Married', 'Jack and Jill', 'The Master of Disguise', 'The Bourne Identity', 'BrainDead', 'Hereafter', 'Topsy-Turvy', 'Circle', '10th & Wolf', "You Don't Mess with the Zohan", 'Hedwig and the Angry Inch', 'Speed 2: Cruise Control', 'xXx: State of the Union', 'Bathing Beauty', 'Harold & Kumar Go to White Castle', 'Tidal Wave', 'The Horse Boy', 'Death Sentence', 'Happiness', 'The Notebook', 'The Boondock Saints II: All Saints Day', "The Caveman's Valentine", 'The Visit', 'Breakdown', 'The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Absentia', 'Walking with Dinosaurs 3D', 'Spice World', 'The Island of Dr. Moreau', 'Disturbing Behavior', 'The Change-Up', 'Margaret', 'Bride Wars', 'Inside Llewyn Davis', 'I Got the Hook Up', 'The Chorus', 'The Rocket: The Legend of Rocket Richard', 'Silent Movie', 'The Rocker', 'Survival of the Dead', 'Chasing Liberty', 'Christmas with the Kranks', 'The Fisher King', 'Shortbus', "Ripley's Game", 'Fatal Attraction', 'The Young and Prodigious T.S. Spivet', 'Cutthroat Island', '300', 'Gods and Monsters', 'An American Carol', 'Blades of Glory', 'The Timber', 'The Hustler', 'Twister', 'Automata', 'Man of the Year', 'The Last Temptation of Christ', 'The Boy in the Striped Pajamas', 'Swelter', 'Kung Fu Panda', 'The 5th Wave', 'Love and Other Catastrophes', 'Annabelle', 'The Bounty', 'Trading Places', "Neal 'N' Nikki", '24 7: Twenty Four Seven', 'Gattaca', 'I Know What You Did Last Summer', 'The Great Train Robbery', 'Western Religion', 'Yoga Hosers', 'Our Idiot Brother', 'Beastmaster 2: Through the Portal of Time', 'Flying By', 'Blood and Wine', 'Point Break', 'Why Did I Get Married?', 'Nixon', 'Royal Kill', 'Mindhunters', 'Chicago', 'I Love You, Man', 'Austin Powers: The Spy Who Shagged Me', 'The Wild Thornberrys Movie', 'Keeping Up with the Steins', 'Tusk', 'Grown ...
# Random selected title for u3 : ['The Road', 'The Unborn', 'Red Lights', 'Bleeding Hearts', 'Thunderbirds', "Legend of the Guardians: The Owls of Ga'Hoole", 'The Hangover Part II', 'The Ant Bully', 'A Shine of Rainbows', 'American Sniper', 'A View to a Kill', 'Beastmaster 2: Through the Portal of Time', 'I Dreamed of Africa', 'Little Shop of Horrors', 'Cars 2', 'Cradle 2 the Grave', 'Anomalisa', 'The Horror Network Vol. 1', '10 Cloverfield Lane', 'The Story of Us', 'All the Pretty Horses', 'All About the Benjamins', 'Inside Man', 'High School Musical 2', 'Terminator Salvation', 'Priest', 'The Missing Person', 'Godsend', 'Gunless', 'Flipper', 'Mr. Smith Goes to Washington', 'Coyote Ugly', 'Billy Elliot', "Barney's Great Adventure", 'The Good, the Bad, the Weird', 'Assault on Precinct 13', 'The Hunger Games: Mockingjay - Part 2', 'Tom Jones', 'Real Steel', 'Home for the Holidays', 'The Wash', 'Little Black Book', 'The Lord of the Rings: The Return of the King', 'The Cell', 'Rango', 'Just Looking', 'The Blood of My Brother', 'My Week with Marilyn', 'Top Gun', 'Abraham Lincoln: Vampire Hunter', 'Bobby', 'The Diary of a Teenage Girl', 'The Nativity Story', 'Legal Eagles', 'The Hangover', 'Slow Burn', 'Death at a Funeral', 'Black Snake Moan', 'The Color of Money', 'Alien: Resurrection', "Howl's Moving Castle", 'A Lego Brickumentary', 'The Water Diviner', 'Martian Child', 'The Guilt Trip', 'Brother', 'The Hunt for Red October', 'Carrie', 'Epic Movie', 'Street Fighter', 'Conan the Destroyer', 'Spy Kids', 'The Widow of Saint-Pierre', 'The Inbetweeners', 'School of Rock', 'A Cinderella Story', 'The Swindle', 'Antibirth', 'Star Wars: The Clone Wars', "Big Momma's House 2", 'Murder by Numbers', 'The Spy Who Loved Me', 'The Chronicles of Narnia: Prince Caspian', 'Small Soldiers', 'Red State', 'This Is 40', 'Anchorman: The Legend of Ron Burgundy', 'Dear Frankie', 'Double Take', 'Little Children', 'Ramanujan', 'The Pet', 'The Secret Life of Walter Mitty', 'Bulletproof Monk', 'Emma', 'Army of Darkness', 'Meet the Parents', 'Percy Jackson & the Olympians: The Lightning Thief', 'The Birth of a Nation', 'The Jungle Book', 'Hansel & Gretel Get Baked', 'Big', 'Bullet to the Head', 'The Shining', 'The Other Side of Heaven', 'Cotton Comes to Harlem', 'Celeste & Jesse Forever', 'Hot Rod', 'Burn', 'Julie & Julia', 'The Fifth Estate', 'Dead Like Me: Life After Death', 'E.T. the Extra-Terrestrial', 'The Grudge 2', 'Easy A', 'Zookeeper', 'Bodyguards and Assassins', 'Chill Factor', 'Reno 911!: Miami', 'Wall Street', 'Mi America', 'The Book of Life', 'Antz', 'Predator 2', 'Limbo', 'Black Rock', "Paris, je t'aime", 'The Greatest Show on Earth', 'See Spot Run', 'Running Forever', 'Top Cat Begins', 'The Score', 'In Dreams', 'Flashdance', 'The History Boys', 'The Piano', 'Flight of the Phoenix', 'The Face of an Angel', 'Patton', 'The Skulls', 'Jack and Jill', 'Animal House', 'Bubba Ho-Tep', 'Love Letters', 'The Twilight Saga: Breaking Dawn - Part 2', 'Chocolat', 'Resident Evil: Extinction', 'Terminator 2: Judgment Day', 'Money Monster', 'Boogie Nights', 'Volver', 'Compadres', 'The Watch', 'The Three Musketeers', 'Be Cool', 'Sholem Aleichem: Laughing in the Darkness', 'Out of the Furnace', 'Kicks', 'The Last Station', 'Thr3e', 'The Black Dahlia', 'Mr. Peabody & Sherman', 'Zipper', 'The Fighter', 'Madadayo', 'The Crazies', 'Imaginary Heroes', 'Diary of the Dead', 'Tropic Thunder', 'Kingdom of Heaven', '3rd Rock from the Sun', 'Just Married', 'Christmas Mail', 'Two Brothers', 'Alice Through the Looking Glass', "Something's Gotta Give", 'The Sweetest Thing', 'Enchanted', 'Me Before You', 'Over the Hill to the Poorhouse', 'Sharknado', 'The Alamo', 'Home Run', 'Paa', 'La Famille BÃ©lier', 'Swept Away', 'The Real Cancun', "I Don't Know How She Does It", 'Strange Wilderness', 'Wild Grass', 'The Claim', 'Bones', 'All Superheroes Must Die', "Straight A's", 'My Dog Skip', 'Rabbit-Proof Fence', "Everybody's Fine", 'The Whole Nine Yards', 'Battleship', 'House of Wax', 'Cler ...
# Random selected title for u4 : ['The Legend of Tarzan', 'Tomorrowland', 'City of God', 'Harriet the Spy', 'Nightcrawler', "The Hitchhiker's Guide to the Galaxy", 'An American in Hollywood', 'Star Trek Into Darkness', 'Strangerland', 'Saint John of Las Vegas', 'Snakes on a Plane', 'The Mask', 'The Merchant of Venice', 'The Legend of Hercules', 'EuroTrip', 'Gosford Park', "The Warrior's Way", 'Eternal Sunshine of the Spotless Mind', 'Happy Feet', 'Pushing Tin', 'Little Women', 'Jack Reacher', 'My Own Private Idaho', 'Cat People', 'Ouija', 'Run Lola Run', "Sarah's Key", 'Flipper', 'The Four Seasons', 'Big Miracle', 'Shutter', 'Stepmom', 'Life', 'The Hammer', 'Mad Max: Fury Road', 'Playing for Keeps', 'The Angry Birds Movie', 'The Great Gatsby', 'Ready to Rumble', 'To Rome with Love', "Gentleman's Agreement", 'The Help', 'A Good Year', 'They Came Together', 'The Grey', 'The Patriot', 'Divine Secrets of the Ya-Ya Sisterhood', 'The Ridiculous 6', 'The Royal Tenenbaums', 'Mr 3000', 'Something Borrowed', 'Little Children', 'Lars and the Real Girl', 'Green Lantern', "It's Complicated", 'Cat on a Hot Tin Roof', 'Locker 13', 'This Is Where I Leave You', 'Meteor', 'From Russia with Love', 'Treachery', 'The Muppets', 'Amigo', 'O', 'Queen Crab', 'The Martian', 'Urban Legends: Final Cut', 'A Million Ways to Die in the West', 'The Wicked Within', 'The Salton Sea', 'The Big Hit', 'Sugar Town', 'Space Cowboys', 'Diner', 'Courage Under Fire', 'Pink Ribbons, Inc.', 'All Is Bright', 'Wild Wild West', 'Once Upon a Time in Queens', 'The Family Stone', 'Next Day Air', 'The Indian in the Cupboard', 'Payback', 'Sherlock Holmes: A Game of Shadows', 'Oz the Great and Powerful', 'Face/Off', 'RiÂ¢hie RiÂ¢h', 'Alone in the Dark', 'Alien Uprising', 'Stargate SG-1', 'Damsels in Distress', 'Lion of the Desert', 'Wind Walkers', "Can't Stop the Music", 'Better Luck Tomorrow', 'The Last Exorcism', 'The Thomas Crown Affair', 'Wyatt Earp', 'Major League', 'Ink', "It's a Mad, Mad, Mad, Mad World", 'The Wild Bunch', 'Before Sunrise', 'Jackass Number Two', 'Bulworth', 'Jason Goes to Hell: The Final Friday', 'Inside Job', 'Sin City: A Dame to Kill For', 'Hail, Caesar!', 'The Clan of the Cave Bear', 'Light from the Darkroom', 'Kung Fu Panda', 'Nothing', 'Agora', 'Reign Over Me', 'Barfi', 'Mr. Deeds', 'Black Book', '50/50', 'Maleficent', 'Spartacus: War of the Damned', "The Legend of Hell's Gate: An American Conspiracy", 'The Image Revolution', 'Unknown', 'World War Z', 'Mercury Rising', 'Riding Giants', 'The Beast from 20,000 Fathoms', 'Imagine Me & You', 'About Time', 'Bridesmaids', 'Things We Lost in the Fire', 'Edmond', 'Another Year', 'Exorcist: The Beginning', 'Good Deeds', 'Rosewater', 'Undercover Brother', 'Alex Rider: Operation Stormbreaker', 'WarGames', 'The Fugitive', 'Sugar Hill', 'Held Up', "Mo' Better Blues", 'Kangaroo Jack', 'Vantage Point', 'Friends with Money', 'Mad City', 'Yu-Gi-Oh! Duel Monsters', 'Tidal Wave', 'The Waterboy', 'Perfect Cowboy', 'A Christmas Story', "Madea's Witness Protection", 'Top Spin', 'Connie and Carla', 'Magic Mike XXL', 'Celebrity', 'Journey to the Center of the Earth', 'Big Eyes', 'Where the Wild Things Are', 'Girls Gone Dead', 'Final Destination 3', 'The Country Bears', 'Arbitrage', 'Northfork', 'Johnson Family Vacation', 'Elysium', 'Nothing But a Man', 'The BFG', 'Hardflip', 'Wonder Boys', 'The Hangover', 'The Doombolt Chase', 'The Celebration', 'In the Name of the King: The Last Job', 'The Rocker', 'Neighbors 2: Sorority Rising', 'Friends with Benefits', 'The King of Najayo', 'American Graffiti', 'The Bold and the Beautiful', 'Bring It On', 'The Messengers', 'The Other Guys', 'Josie and the Pussycats', 'The Powerpuff Girls', 'Chicago', "Donovan's Reef", 'Planet of the Apes', 'Ronin', 'November', 'Batman Begins', 'Election', 'The Sixth Sense', 'Live Free or Die Hard', 'Spaceballs', 'Poseidon', 'Scott Pilgrim vs. the World', 'Full Frontal', 'Casino Jack', 'Road Trip', 'Summer of Sam', 'The Dark Hours', 'Double Take', 'The Glim ...
# Random selected title for u5 : ['The Oh in Ohio', 'Star Trek: First Contact', 'The Possession', 'Perfume: The Story of a Murderer', 'The Watch', "Big Momma's House", 'The Watch', 'After the Sunset', 'The Tourist', 'Twister', 'A Good Day to Die Hard', '3:10 to Yuma', 'Fighting Tommy Riley', 'Show Boat', 'Slow Burn', 'Sphinx', 'Supernova', 'It Follows', 'The Man from Snowy River', 'Stories of Our Lives', 'Gothika', 'The Homesman', 'ZMD: Zombies of Mass Destruction', 'Haywire', 'Jack Reacher', 'Lisa Picard Is Famous', 'Body of Lies', 'Rugrats Go Wild', 'Gomorrah', 'Munich', 'Sleepers', 'Rush Hour 2', 'Vaalu', 'The Next Best Thing', 'The Number 23', 'Willard', 'Planet of the Apes', 'Machine Gun Preacher', 'Decoys', 'The Legend of Hercules', 'Twilight', 'Paranormal Activity 2', "Wayne's World", 'The Adventurer: The Curse of the Midas Box', 'Guardians of the Galaxy', 'The A-Team', 'Lakeview Terrace', 'Duplex', 'Observe and Report', 'The Hotel New Hampshire', 'Out of the Blue', 'Clockstoppers', 'Syriana', 'Secretariat', 'The Lincoln Lawyer', 'Captain America: Civil War', 'The Haunting in Connecticut 2: Ghosts of Georgia', 'Going the Distance', 'The Mist', 'Godzilla Resurgence', 'Mulan', 'Seven Pounds', 'The Equalizer', 'From Russia with Love', 'We Were Soldiers', 'History of the World: Part I', 'The Bourne Supremacy', "The Caveman's Valentine", 'Zoolander', 'King Kong', 'Zombieland', 'Race', 'Monsters, Inc.', 'Indignation', 'Lars and the Real Girl', 'World War Z', 'The Guard', 'The Rules of Attraction', 'Bizarre', 'Maria Full of Grace', 'The Grace Card', 'Flight of the Intruder', 'The Fast and the Furious: Tokyo Drift', 'Martin Lawrence Live: Runteldat', 'High Anxiety', 'The Dark Hours', 'Radio Flyer', 'Tango', 'Night at the Museum: Secret of the Tomb', 'The Blind Side', 'Jumper', 'The Others', 'Cutthroat Island', 'Spartacus: War of the Damned', 'Stoker', 'Cop Land', '1982', 'The Book of Mormon Movie, Volume 1: The Journey', '16 Blocks', 'CJ7', 'Open Water', 'Finding Neverland', 'I Still Know What You Did Last Summer', 'The Mummy Returns', 'Dogtown and Z-Boys', 'Splice', 'G.I. Joe: The Rise of Cobra', 'Outlander', 'Delgo', 'Nanny McPhee', '17 Again', 'They Came Together', 'Under the Tuscan Sun', 'Harold & Kumar Escape from Guantanamo Bay', 'A Room for Romeo Brass', 'We Have Your Husband', 'Get Him to the Greek', 'The Conversation', 'Namastey London', 'Planet 51', "Everybody's Fine", 'The Reef', 'The Lion King', 'Rise of the Planet of the Apes', 'My Favorite Martian', 'Mooz-Lum', 'Witless Protection', 'Around the World in 80 Days', 'Roll Bounce', 'DOA: Dead or Alive', 'Unfriended', 'Now You See Me 2', 'Forsaken', 'Unbroken', 'Real Women Have Curves', 'Cruel Intentions', 'Madadayo', 'The Game Plan', 'Fugly', 'The Player', 'Mercy Streets', "Cirque du Freak: The Vampire's Assistant", 'Khumba', 'Rang De Basanti', 'Kung Fu Panda', 'Peaceful Warrior', 'Standing Ovation', 'Excessive Force', 'Fight Valley', 'Star Trek: Nemesis', 'Love Stinks', 'Never Say Never Again', 'The Rock', 'Freaky Friday', 'Serendipity', 'X-Men: Apocalypse', 'The Spectacular Now', 'The Giver', 'Bullet to the Head', 'Skyline', 'The Adventures of Rocky & Bullwinkle', 'Monte Carlo', 'Don Jon', 'Precious', 'The Libertine', 'The Five-Year Engagement', 'Fever Pitch', 'I Come with the Rain', 'Interstellar', 'Fantastic Mr. Fox', 'The Lovers', 'The Girl on the Train', 'Star Trek: The Motion Picture', 'Step Up Revolution', 'In the Heart of the Sea', 'The Nutty Professor', 'Purple Violets', 'Mondays in the Sun', 'Inception', 'The Day the Earth Stood Still', 'The Missing', 'A Most Violent Year', 'Albert Nobbs', 'Doubt', 'Meet the Browns', 'Here on Earth', 'The Jimmy Show', 'Arthur Christmas', 'Sinister 2', 'Scrooged', 'Swing Vote', "Jennifer's Body", 'College', 'Poetic Justice', 'The Californians', 'Faster', 'The Quiet', 'The Box', 'Twilight Zone: The Movie', 'The Cry of the Owl', 'Fear and Loathing in Las Vegas', 'Layer Cake', 'Rush Hour', 'Seven Psychopaths', 'The Mongol King',  ...

# %%
def jaccard_similarity(x,y):
      intersection_cardinality=len(set.intersection(*[set(x),set(y)]))
      union_cardinality=len(set.union(*[set(x),set(y)]))
      return intersection_cardinality/float(union_cardinality)

# %%
a=(jaccard_similarity(u1,u2))
print ("Jaccard Similarity btw u1 and u2 : " + str(a))
b=(jaccard_similarity(u1,u3))
print ("Jaccard Similarity btw u1 and u3 : " + str(b))
c=(jaccard_similarity(u1,u4))
print ("Jaccard Similarity btw u1 and u4 : " + str(c))
d=(jaccard_similarity(u1,u5))
print ("Jaccard Similarity btw u1 and u5 : " + str(d))
# Out:
# Jaccard Similarity btw u1 and u2 : 0.1639549436795995
# Jaccard Similarity btw u1 and u3 : 0.17109256449165403
# Jaccard Similarity btw u1 and u4 : 0.165890816758358
# Jaccard Similarity btw u1 and u5 : 0.16350906095551895

# %%
def intersect(a, b):
    return list(set(a) & set(b))

# %%
def union(a, b):
    return list(set(a) | set(b))

def Diff(li1, li2): 
    return (list(set(li1) - set(li2)))

# %%
if (a >= b) and (a >= c) and (a >=d):
      largest = 'a'
      z="u1 and u2"
      intersectionn=(intersect(u1, u2))
      unionn=(union(u1, u2))
      RecomList=(Diff(u1, u2))
elif (b >= a) and (b >= c) and (b >=d):
      largest = 'b'
      z="u1 and u3"
      intersectionn=(intersect(u1, u3))
      unionn=(union(u1, u3))
      RecomList=(Diff(u1, u3))
elif (c >= a) and (c >= b) and (c >=d):
      largest = 'c'
      z="u1 and u4"
      intersectionn=(intersect(u1, u4))
      unionn=(union(u1, u4))
      RecomList=(Diff(u1, u4))
else:
      largest = 'd'
      z="u1 and u5"
      intersectionn=(intersect(u1, u5))
      unionn=(union(u1, u5))
      RecomList=(Diff(u1, u5))

# %%
print("The highest similarity is between", z)
# Out:
# The highest similarity is between u1 and u3

# %%
print ("Recommanded movies for u1 on basis of similarity score between " + str(z), end=" "),
#print ("are : " + str(RecomList))
print("are :")
print(str(RecomList))
# Out:
# Recommanded movies for u1 on basis of similarity score between u1 and u3 are :
# ['Shanghai Calling', 'Life During Wartime', 'WALLÂ·E', 'Howard the Duck', 'The Way of the Gun', 'Monty Python and the Holy Grail', 'TMNT', 'The Veil', 'Final Destination 2', 'Skin Trade', 'Music and Lyrics', "Daddy's Home", 'Desert Dancer', 'Fargo', 'My Fair Lady', 'The Image Revolution', 'The Good Dinosaur', 'Hail, Caesar!', "A Turtle's Tale: Sammy's Adventures", 'Freeze Frame', 'Henry V', 'Stealth', 'Road Trip', 'Double Jeopardy', 'The Conversation', 'Outbreak', 'Puss in Boots', 'The Lego Movie', 'Hocus Pocus', 'Super', 'A Mighty Wind', 'An Education', 'The Visit', 'The Host', 'Riddick', 'Escape from Alcatraz', 'Out of Time', 'Braveheart', 'Holes', 'Flubber', 'Stepmom', 'Manito', 'Jonah Hex', 'Pathology', 'Taxman', 'The SpongeBob Movie: Sponge Out of Water', 'PCU', 'Johnny English Reborn', 'The Brothers Grimm', 'Speed', 'Confessions of a Dangerous Mind', 'The Eye', 'Red Tails', 'Ride Along', 'Dumb & Dumber', 'The Best Little Whorehouse in Texas', "While We're Young", 'Ninja Assassin', 'Samsara', 'Tucker and Dale vs Evil', 'The Lovers', 'Buffy the Vampire Slayer', 'Mr. Nice Guy', 'Hotel Rwanda', 'State of Play', 'The Darkest Hour', 'A Lonely Place to Die', 'Party Monster', 'The Stepford Wives', 'The Green Inferno', 'Freakonomics', 'Nikita', 'Jeepers Creepers', 'In the Heat of the Night', 'The Sweeney', 'Star Trek: Insurrection', 'Godzilla Resurgence', 'Miracles from Heaven', 'The Dark Hours', 'The Bourne Ultimatum', 'Munich', 'Fascination', 'The Magic Sword: Quest for Camelot', 'Run Lola Run', 'Bridesmaids', 'Larry the Cable Guy: Health Inspector', 'Lisa Picard Is Famous', 'The Perfect Storm', 'Beverly Hills Cop', 'My Big Fat Greek Wedding', 'Session 9', 'Lottery Ticket', 'Anastasia', "Buffalo '66", 'Disclosure', 'Princess Mononoke', 'Nighthawks', 'The Girl on the Train', 'Flags of Our Fathers', 'Southland Tales', 'Justin Bieber: Never Say Never', 'Crank: High Voltage', 'White Squall', 'Ghost', 'Wild Target', 'Universal Soldier: The Return', 'This Means War', 'Live-In Maid', 'Clear and Present Danger', "Trippin'", 'Holy Motors', 'Neighbors 2: Sorority Rising', 'The Lion of Judah', 'Dodgeball: A True Underdog Story', 'Videodrome', 'House at the End of the Drive', "Hart's War", "Legends of Oz: Dorothy's Return", 'Basquiat', 'Gentlemen Broncos', 'Stone Cold', 'Apollo 18', 'Phone Booth', 'The Dead Girl', 'Spy Kids 3-D: Game Over', 'The Wiz', 'Taxi Driver', 'It Follows', 'Riding in Cars with Boys', 'Super 8', "The Emperor's New Groove", 'Extraordinary Measures', 'Heaven Is for Real', 'Pierrot le Fou', 'I Spit on Your Grave', 'The Last Airbender', 'The Flowers of War', 'Across the Universe', 'A Funny Thing Happened on the Way to the Forum', 'Give Me Shelter', 'Mr 3000', 'Before Sunrise', 'Spectre', 'Doubt', 'The Living Daylights', 'Need for Speed', 'I Want Someone to Eat Cheese With', 'Little Big Top', 'Pirates of the Caribbean: On Stranger Tides', 'Post Grad', 'P.S. I Love You', 'The Heart of Me', 'Frozen River', 'High Noon', 'Hum To Mohabbat Karega', 'Seven Samurai', 'Somewhere', 'Area 51', 'The Shallows', 'American Graffiti', "Perrier's Bounty", "Barney's Version", 'I, Robot', 'Money Talks', 'On the Waterfront', 'Jade', 'Bloody Sunday', 'The Rocker', 'My Last Day Without You', 'Tiger Orange', 'Labor Day', 'Shooter', 'Last Holiday', 'Men in Black 3', 'Corky Romano', '27 Dresses', "Tim and Eric's Billion Dollar Movie", 'Burnt', "Singin' in the Rain", 'Minority Report', 'Melancholia', 'Saving Mr. Banks', 'Ride with the Devil', 'Lage Raho Munna Bhai', 'Some Like It Hot', 'The Hustler', 'Mission to Mars', 'Mona Lisa Smile', 'Rushmore', 'Remember Me', 'Fast Five', 'Speedway Junky', 'Parental Guidance', 'Shopgirl', 'Dick Tracy', 'Pandorum', 'Collateral', 'Cast Away', 'Modern Times', 'Darkness', 'Dark Angel', 'The Cookout', 'Shipwrecked', 'Wild Wild West', 'The R.M.', 'How She Move', 'Everest', 'The Patriot', 'America Is Still the Place', 'Green Street 3: Never Back Down', 'The Algerian', 'The Punisher', 'Star Trek III: The Search for S ...
